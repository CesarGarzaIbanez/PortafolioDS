# %% [markdown]
# # Practica de CV

# %%
# Credenciales
key  = "2230858a69384b92bb75859867535dab"
endpoint = "https://lab-ai.cognitiveservices.azure.com/"

# %%
#Conexión con Azure

from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from msrest.authentication import CognitiveServicesCredentials

client = ComputerVisionClient(endpoint, CognitiveServicesCredentials(key))

# %%
import vision 
import os

# %matplotlib inline 

#Obtener imagen

img_path = "./Data/Vision/grupo.jpg"

img_stream = open(img_path, 'rb')

description = client.describe_image_in_stream(img_stream)

vision.show_image_caption(img_path, description)

# %%
img_path = "./Data/Vision/juego.jpg"

img_stream = open(img_path, 'rb')

description = client.describe_image_in_stream(img_stream)

vision.show_image_caption(img_path, description)

# %%
img_path = "./Data/Vision/grupo.jpg"

img_stream = open(img_path, 'rb')

features = ['Description', 'Tags', 'Adult', 'Objects', 'Faces']

analysis = client.analyze_image_in_stream(img_stream, visual_features = features)

vision.show_image_analysis(img_path, analysis)

# %% [markdown]
# ## FaceAPI

# %%
#key 

key = "b0305558be9242bc9207b769179cb856"
endpoint = "https://lab-face-cv.cognitiveservices.azure.com/"

# %%
#Conexión con Azure

from azure.cognitiveservices.vision.face import FaceClient
from msrest.authentication import CognitiveServicesCredentials

client = FaceClient(endpoint, CognitiveServicesCredentials(key))

# %%
import faces
import os
# %matplotlib inline

# %%
img_path = "./Data/Vision/grupo.jpg"

img_stream = open(img_path, 'rb')

detected_faces = client.face.detect_with_stream(img_stream)

faces.show_faces(img_path, detected_faces)

# %%
img_path = "./Data/Vision/grupo.jpg"

img_stream = open(img_path, 'rb')

detected_faces = client.face.detect_with_stream(img_stream)

faces.show_faces(img_path, detected_faces, show_id= True)

# %%
img_path = "./Data/Vision/grupo.jpg"

img_stream = open(img_path, 'rb')

attributes = ['age','emotion']

detected_faces = client.face.detect_with_stream(img_stream, return_face_attributes= attributes)

faces.show_face_attributes(img_path,detected_faces)

# %%
img_path = "./Data/Vision/arg.jpg"

img_stream = open(img_path, 'rb')

attributes = ['age','emotion']

detected_faces = client.face.detect_with_stream(img_stream, return_face_attributes= attributes)

faces.show_face_attributes(img_path,detected_faces)
